# %% [markdown]
# <a href="https://colab.research.google.com/github/Vassudev22/EDA-Lab-L41-L42-/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
dataFrame1 = pd.DataFrame({
'StudentID': [1, 3, 5, 7, 9],
'Score': [89, 39, 50, 97, 22]
})
dataFrame2 = pd.DataFrame({
'StudentID': [2, 4, 6, 8, 10],
'Score': [98, 93, 44, 77, 69]
})
vertical_concat = pd.concat([dataFrame1, dataFrame2], ignore_index=True)
print("Vertical Concatenation:")
print(vertical_concat)
horizontal_concat = pd.concat([dataFrame1, dataFrame2], axis=1)
print("\nHorizontal Concatenation:")
print(horizontal_concat)
# Out:
# Vertical Concatenation:
#    StudentID  Score
# 0          1     89
# 1          3     39
# 2          5     50
# 3          7     97
# 4          9     22
# 5          2     98
# 6          4     93
# 7          6     44
# 8          8     77
# 9         10     69
#
# Horizontal Concatenation:
#    StudentID  Score  StudentID  Score
# 0          1     89          2     98
# 1          3     39          4     93
# 2          5     50          6     44
# 3          7     97          8     77
# 4          9     22         10     69
