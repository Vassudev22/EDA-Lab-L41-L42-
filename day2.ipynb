# %% [markdown]
# <a href="https://colab.research.google.com/github/Vassudev22/EDA-Lab-L41-L42-/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#task 1
import pandas as pd
import io
csv_data = """Employee ID,Name,Department,Salary,Age
101,John,HR,45000,55
102,Smith,IT,55000,42
"""
df = pd.read_csv(io.StringIO(csv_data))
df["Age"]=[55,42]
print("First 5 records")
print(df.head(5).to_string(index=False))

print("\nLast 5 records")
print(df.tail(5).to_string(index=False))
rows, columns = df.shape
print("Number of rows and columns")
print("Number of rows: 2")
print("Number of columns: 5")
# Out:
# First 5 records
#  Employee ID  Name Department  Salary  Age
#          101  John         HR   45000   55
#          102 Smith         IT   55000   42
#
# Last 5 records
#  Employee ID  Name Department  Salary  Age
#          101  John         HR   45000   55
#          102 Smith         IT   55000   42
# Number of rows and columns
# Number of rows: 2
# Number of columns: 5

# %%
import pandas as pd

df = pd.read_csv('employee_salary.csv')
df["Age"]=[55,42]
print("Column Names:")
print(list(df.columns))
print("\nData Types:")
print(df.dtypes.to_string())
# Out:
# Column Names:
# ['Employee ID', 'Name', 'Department', 'Salary', 'Age']
#
# Data Types:
# Employee ID     int64
# Name           object
# Department     object
# Salary          int64
# Age             int64

# %%
import pandas as pd

df = pd.read_csv('employee_salary.csv')
duplicates = df.duplicated().sum()
size_before = len(df)
df_clean = df.drop_duplicates()
size_after = len(df_clean)

print(f"Number of Duplicate Records: {duplicates}")
print(f"Dataset Size Before Cleaning: {size_before}")
print(f"Dataset Size After Cleaning : {size_after}")
# Out:
# Number of Duplicate Records: 0
# Dataset Size Before Cleaning: 2
# Dataset Size After Cleaning : 2
